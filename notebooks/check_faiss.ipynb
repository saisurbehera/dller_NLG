# %% [markdown]
# # Check Faiss works
#
# In this file, let us explore the embeddings we encoded actually can be searchable by faiss

# %%
from datasets import load_from_disk
ds= load_from_disk("/workspace/data/filtered_split_dprc_sentences_embeddings")
ds
# Out:
# Dataset({
#     features: ['date', 'hash', 'title', 'sentence', 'embeddings'],
#     num_rows: 3034846
# })

# %%
# convert 2d embedding to 1d
import numpy as np
ds = ds.map(lambda example: {'embeddings': example["embeddings"][0]},num_proc=32)
# Out:
# #0:   0%|          | 0/94839 [00:00<?, ?ex/s]
#
#
# #3:   0%|          | 0/94839 [00:00<?, ?ex/s]
#
#
#
#
#
#
#
#
#
#
#
# #0:   0%|          | 339/94839 [00:00<00:27, 3380.70ex/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #11:   0%|          | 0/94839 [00:00<?, ?ex/s]
#
#
#
#
#
#
#
#
#
#
#
# #0:   1%|          | 678/94839 [00:00<00:32, 2902.46ex/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #0:   1%|          | 973/94839 [00:00<00:34, 2749.48ex/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
ds.add_faiss_index(column='embeddings')
# Out:
#   0%|          | 0/3035 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 ds.add_faiss_index(column='embeddings')
#
# File /workspace/dller_NLG/.conda/lib/python3.8/site-packages/datasets/arrow_dataset.py:4738, in Dataset.add_faiss_index(self, column, index_name, device, string_factory, metric_type, custom_index, batch_size, train_size, faiss_verbose, dtype)
#    4687 """Add a dense index using Faiss for fast retrieval.
#    4688 By default the index is done over the vectors of the specified column.
#    4689 You can specify :obj:`device` if you want to run it on GPU (:obj:`device` must be the GPU index).
#    (...)
#    4735 ```
#    4736 """
#    4737 with self.formatted_as(type="numpy", columns=[column], dtype=dtype):
# -> 4738     super().add_faiss_index(
#    4739         column=column,
# ...

# %%
# ds[0]
# Out:
# {'date': 20080101,
#  'hash': '3d6943d8ea557c6b60bd9b88474c2f68751e72d7993ff577db667d5b9c8df510',
#  'title': 'Radiohead - Music - New York Times',
#  'sentence': 'LOS ANGELES - "In Rainbows," the latest album from the British rock band Radiohead, has been readily available to music fans for almost three months, first as a digital download in an unconventional tip-jar offering in which fans decided for themselves what to pay for it, and then, like most pop music today, as digital files circulating on free, unlicensed file-swapping networks. One matter remains: Will anyone buy the CD?',
#  'embeddings': [[0.9448727965354919,
#    -0.015278792940080166,
#    0.3544004261493683,
#    0.44568008184432983,
#    -0.06354698538780212,
#    -0.12772324681282043,
#    -0.018529176712036133,
#    0.31041887402534485,
#    -0.39970189332962036,
#    0.13250276446342468,
#    -0.012911539524793625,
#    0.7225227952003479,
#    0.09846609830856323,
#    -0.13115060329437256,
# ...
